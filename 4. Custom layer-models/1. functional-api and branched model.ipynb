# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 892us/sample - loss: 275.3546 - y1_output_loss: 126.8554 - y2_output_loss: 146.5569 - y1_output_root_mean_squared_error: 11.3027 - y2_output_root_mean_squared_error: 12.1493 - val_loss: 35.0496 - val_y1_output_loss: 17.1976 - val_y2_output_loss: 19.3109 - val_y1_output_root_mean_squared_error: 4.1542 - val_y2_output_root_mean_squared_error: 4.2181
# Epoch 2/500
# 614/614 [==============================] - 0s 136us/sample - loss: 33.5049 - y1_output_loss: 12.9761 - y2_output_loss: 20.6068 - y1_output_root_mean_squared_error: 3.6036 - y2_output_root_mean_squared_error: 4.5298 - val_loss: 61.6103 - val_y1_output_loss: 16.7666 - val_y2_output_loss: 45.6134 - val_y1_output_root_mean_squared_error: 4.1126 - val_y2_output_root_mean_squared_error: 6.6856
# Epoch 3/500
# 614/614 [==============================] - 0s 154us/sample - loss: 28.3538 - y1_output_loss: 10.6073 - y2_output_loss: 17.5324 - y1_output_root_mean_squared_error: 3.2708 - y2_output_root_mean_squared_error: 4.2019 - val_loss: 25.2219 - val_y1_output_loss: 11.1806 - val_y2_output_loss: 16.0869 - val_y1_output_root_mean_squared_error: 3.2828 - val_y2_output_root_mean_squared_error: 3.8007
# Epoch 4/500
# 614/614 [==============================] - 0s 133us/sample - loss: 24.2256 - y1_output_loss: 9.5057 - y2_output_loss: 14.7208 - y1_output_root_mean_squared_error: 3.0871 - y2_output_root_mean_squared_error: 3.8335 - val_loss: 22.0803 - val_y1_output_loss: 10.6651 - val_y2_output_loss: 12.9113 - val_y1_output_root_mean_squared_error: 3.2335 - val_y2_output_root_mean_squared_error: 3.4095
# Epoch 5/500
# 614/614 [==============================] - 0s 130us/sample - loss: 25.5631 - y1_output_loss: 9.6422 - y2_output_loss: 15.8071 - y1_output_root_mean_squared_error: 3.1028 - y2_output_root_mean_squared_error: 3.9919 - val_loss: 26.4293 - val_y1_output_loss: 13.6583 - val_y2_output_loss: 12.9194 - val_y1_output_root_mean_squared_error: 3.7351 - val_y2_output_root_mean_squared_error: 3.5325
# Epoch 6/500
# 614/614 [==============================] - 0s 128us/sample - loss: 23.6096 - y1_output_loss: 8.9868 - y2_output_loss: 14.5039 - y1_output_root_mean_squared_error: 3.0051 - y2_output_root_mean_squared_error: 3.8182 - val_loss: 20.2556 - val_y1_output_loss: 9.5740 - val_y2_output_loss: 12.8162 - val_y1_output_root_mean_squared_error: 3.0109 - val_y2_output_root_mean_squared_error: 3.3451
# Epoch 7/500
# 614/614 [==============================] - 0s 126us/sample - loss: 22.2882 - y1_output_loss: 8.7024 - y2_output_loss: 13.4768 - y1_output_root_mean_squared_error: 2.9605 - y2_output_root_mean_squared_error: 3.6775 - val_loss: 26.2747 - val_y1_output_loss: 10.6858 - val_y2_output_loss: 17.1317 - val_y1_output_root_mean_squared_error: 3.2171 - val_y2_output_root_mean_squared_error: 3.9906
# Epoch 8/500
# 614/614 [==============================] - 0s 130us/sample - loss: 21.1306 - y1_output_loss: 8.3452 - y2_output_loss: 12.6305 - y1_output_root_mean_squared_error: 2.9005 - y2_output_root_mean_squared_error: 3.5662 - val_loss: 20.2252 - val_y1_output_loss: 9.1718 - val_y2_output_loss: 12.2321 - val_y1_output_root_mean_squared_error: 2.9969 - val_y2_output_root_mean_squared_error: 3.3532
# Epoch 9/500
# 614/614 [==============================] - 0s 132us/sample - loss: 28.0031 - y1_output_loss: 9.7196 - y2_output_loss: 18.3889 - y1_output_root_mean_squared_error: 3.1008 - y2_output_root_mean_squared_error: 4.2882 - val_loss: 30.9019 - val_y1_output_loss: 10.4144 - val_y2_output_loss: 21.4317 - val_y1_output_root_mean_squared_error: 3.2056 - val_y2_output_root_mean_squared_error: 4.5416
# Epoch 10/500
# 614/614 [==============================] - 0s 131us/sample - loss: 21.0081 - y1_output_loss: 8.1901 - y2_output_loss: 12.6702 - y1_output_root_mean_squared_error: 2.8719 - y2_output_root_mean_squared_error: 3.5721 - val_loss: 20.0496 - val_y1_output_loss: 9.3148 - val_y2_output_loss: 12.0173 - val_y1_output_root_mean_squared_error: 3.0210 - val_y2_output_root_mean_squared_error: 3.3050
# Epoch 11/500
# 614/614 [==============================] - 0s 131us/sample - loss: 22.1627 - y1_output_loss: 8.3989 - y2_output_loss: 13.7491 - y1_output_root_mean_squared_error: 2.8865 - y2_output_root_mean_squared_error: 3.7190 - val_loss: 32.0585 - val_y1_output_loss: 12.2089 - val_y2_output_loss: 20.7863 - val_y1_output_root_mean_squared_error: 3.4779 - val_y2_output_root_mean_squared_error: 4.4680
# Epoch 12/500
# 614/614 [==============================] - 0s 130us/sample - loss: 19.5544 - y1_output_loss: 7.8637 - y2_output_loss: 11.5651 - y1_output_root_mean_squared_error: 2.8146 - y2_output_root_mean_squared_error: 3.4107 - val_loss: 19.7847 - val_y1_output_loss: 8.7692 - val_y2_output_loss: 11.5608 - val_y1_output_root_mean_squared_error: 2.9718 - val_y2_output_root_mean_squared_error: 3.3095
# Epoch 13/500
# 614/614 [==============================] - 0s 126us/sample - loss: 20.9118 - y1_output_loss: 8.5410 - y2_output_loss: 13.2458 - y1_output_root_mean_squared_error: 2.8779 - y2_output_root_mean_squared_error: 3.5538 - val_loss: 109.3562 - val_y1_output_loss: 28.5821 - val_y2_output_loss: 87.0500 - val_y1_output_root_mean_squared_error: 5.2081 - val_y2_output_root_mean_squared_error: 9.0682
# Epoch 14/500
# 614/614 [==============================] - 0s 130us/sample - loss: 21.6883 - y1_output_loss: 8.0032 - y2_output_loss: 13.5328 - y1_output_root_mean_squared_error: 2.8408 - y2_output_root_mean_squared_error: 3.6903 - val_loss: 19.7662 - val_y1_output_loss: 8.2041 - val_y2_output_loss: 12.9376 - val_y1_output_root_mean_squared_error: 2.8063 - val_y2_output_root_mean_squared_error: 3.4483
# Epoch 15/500
# 614/614 [==============================] - 0s 127us/sample - loss: 20.8529 - y1_output_loss: 8.0967 - y2_output_loss: 12.5948 - y1_output_root_mean_squared_error: 2.8548 - y2_output_root_mean_squared_error: 3.5641 - val_loss: 18.3547 - val_y1_output_loss: 7.7715 - val_y2_output_loss: 11.2248 - val_y1_output_root_mean_squared_error: 2.7758 - val_y2_output_root_mean_squared_error: 3.2634
# Epoch 16/500
# 614/614 [==============================] - 0s 127us/sample - loss: 26.8166 - y1_output_loss: 8.9261 - y2_output_loss: 18.0964 - y1_output_root_mean_squared_error: 2.9790 - y2_output_root_mean_squared_error: 4.2358 - val_loss: 50.8182 - val_y1_output_loss: 11.9248 - val_y2_output_loss: 39.4227 - val_y1_output_root_mean_squared_error: 3.4490 - val_y2_output_root_mean_squared_error: 6.2388
# Epoch 17/500
# 614/614 [==============================] - 0s 126us/sample - loss: 18.6267 - y1_output_loss: 7.0470 - y2_output_loss: 11.4861 - y1_output_root_mean_squared_error: 2.6637 - y2_output_root_mean_squared_error: 3.3958 - val_loss: 54.6982 - val_y1_output_loss: 16.4627 - val_y2_output_loss: 39.2305 - val_y1_output_root_mean_squared_error: 4.0401 - val_y2_output_root_mean_squared_error: 6.1948
# Epoch 18/500
# 614/614 [==============================] - 0s 126us/sample - loss: 20.1740 - y1_output_loss: 7.5100 - y2_output_loss: 12.9198 - y1_output_root_mean_squared_error: 2.7246 - y2_output_root_mean_squared_error: 3.5708 - val_loss: 24.4622 - val_y1_output_loss: 7.8526 - val_y2_output_loss: 17.0102 - val_y1_output_root_mean_squared_error: 2.7986 - val_y2_output_root_mean_squared_error: 4.0780
# Epoch 19/500
# 614/614 [==============================] - 0s 131us/sample - loss: 17.5427 - y1_output_loss: 6.7225 - y2_output_loss: 10.7495 - y1_output_root_mean_squared_error: 2.6010 - y2_output_root_mean_squared_error: 3.2829 - val_loss: 22.8375 - val_y1_output_loss: 8.8057 - val_y2_output_loss: 15.4660 - val_y1_output_root_mean_squared_error: 2.9240 - val_y2_output_root_mean_squared_error: 3.7799
# Epoch 20/500
# 614/614 [==============================] - 0s 147us/sample - loss: 16.4898 - y1_output_loss: 6.3195 - y2_output_loss: 10.0681 - y1_output_root_mean_squared_error: 2.5205 - y2_output_root_mean_squared_error: 3.1839 - val_loss: 16.8089 - val_y1_output_loss: 7.2489 - val_y2_output_loss: 10.8739 - val_y1_output_root_mean_squared_error: 2.6417 - val_y2_output_root_mean_squared_error: 3.1353
# Epoch 21/500
# 614/614 [==============================] - 0s 129us/sample - loss: 17.4492 - y1_output_loss: 6.5928 - y2_output_loss: 10.7015 - y1_output_root_mean_squared_error: 2.5780 - y2_output_root_mean_squared_error: 3.2868 - val_loss: 15.8271 - val_y1_output_loss: 6.9666 - val_y2_output_loss: 9.5883 - val_y1_output_root_mean_squared_error: 2.6263 - val_y2_output_root_mean_squared_error: 2.9882
# Epoch 22/500
# 614/614 [==============================] - 0s 126us/sample - loss: 18.1267 - y1_output_loss: 6.4605 - y2_output_loss: 11.5533 - y1_output_root_mean_squared_error: 2.5499 - y2_output_root_mean_squared_error: 3.4095 - val_loss: 17.4611 - val_y1_output_loss: 7.0606 - val_y2_output_loss: 11.0522 - val_y1_output_root_mean_squared_error: 2.6498 - val_y2_output_root_mean_squared_error: 3.2311
# Epoch 23/500
# 614/614 [==============================] - 0s 128us/sample - loss: 14.4076 - y1_output_loss: 5.6391 - y2_output_loss: 9.0407 - y1_output_root_mean_squared_error: 2.3732 - y2_output_root_mean_squared_error: 2.9623 - val_loss: 88.9026 - val_y1_output_loss: 16.6702 - val_y2_output_loss: 72.0966 - val_y1_output_root_mean_squared_error: 4.1138 - val_y2_output_root_mean_squared_error: 8.4841
# Epoch 24/500
# 614/614 [==============================] - 0s 126us/sample - loss: 23.3676 - y1_output_loss: 7.5418 - y2_output_loss: 15.7102 - y1_output_root_mean_squared_error: 2.7537 - y2_output_root_mean_squared_error: 3.9730 - val_loss: 22.5291 - val_y1_output_loss: 8.4158 - val_y2_output_loss: 14.4018 - val_y1_output_root_mean_squared_error: 2.9030 - val_y2_output_root_mean_squared_error: 3.7552
# Epoch 25/500
# 614/614 [==============================] - 0s 133us/sample - loss: 15.7650 - y1_output_loss: 6.0310 - y2_output_loss: 9.6940 - y1_output_root_mean_squared_error: 2.4589 - y2_output_root_mean_squared_error: 3.1175 - val_loss: 18.5450 - val_y1_output_loss: 7.6605 - val_y2_output_loss: 11.7308 - val_y1_output_root_mean_squared_error: 2.7522 - val_y2_output_root_mean_squared_error: 3.3121
# Epoch 26/500
# 614/614 [==============================] - 0s 132us/sample - loss: 15.3262 - y1_output_loss: 5.6922 - y2_output_loss: 9.6190 - y1_output_root_mean_squared_error: 2.3841 - y2_output_root_mean_squared_error: 3.1052 - val_loss: 18.4607 - val_y1_output_loss: 5.7912 - val_y2_output_loss: 13.4017 - val_y1_output_root_mean_squared_error: 2.4102 - val_y2_output_root_mean_squared_error: 3.5569
# Epoch 27/500
# 614/614 [==============================] - 0s 130us/sample - loss: 16.8590 - y1_output_loss: 6.0667 - y2_output_loss: 10.7845 - y1_output_root_mean_squared_error: 2.4688 - y2_output_root_mean_squared_error: 3.2809 - val_loss: 18.6942 - val_y1_output_loss: 6.8025 - val_y2_output_loss: 11.5772 - val_y1_output_root_mean_squared_error: 2.6453 - val_y2_output_root_mean_squared_error: 3.4200
# Epoch 28/500
# 614/614 [==============================] - 0s 128us/sample - loss: 14.3634 - y1_output_loss: 5.2643 - y2_output_loss: 9.0365 - y1_output_root_mean_squared_error: 2.3049 - y2_output_root_mean_squared_error: 3.0084 - val_loss: 16.9572 - val_y1_output_loss: 6.3449 - val_y2_output_loss: 10.6624 - val_y1_output_root_mean_squared_error: 2.5316 - val_y2_output_root_mean_squared_error: 3.2478
# Epoch 29/500
# 614/614 [==============================] - 0s 131us/sample - loss: 12.9042 - y1_output_loss: 4.7825 - y2_output_loss: 8.0089 - y1_output_root_mean_squared_error: 2.1962 - y2_output_root_mean_squared_error: 2.8427 - val_loss: 13.2242 - val_y1_output_loss: 5.0244 - val_y2_output_loss: 8.9618 - val_y1_output_root_mean_squared_error: 2.2213 - val_y2_output_root_mean_squared_error: 2.8792
# Epoch 30/500
# 614/614 [==============================] - 0s 136us/sample - loss: 13.1054 - y1_output_loss: 4.8810 - y2_output_loss: 8.2882 - y1_output_root_mean_squared_error: 2.2006 - y2_output_root_mean_squared_error: 2.8745 - val_loss: 13.6639 - val_y1_output_loss: 5.7815 - val_y2_output_loss: 8.5951 - val_y1_output_root_mean_squared_error: 2.3731 - val_y2_output_root_mean_squared_error: 2.8342
# Epoch 31/500
# 614/614 [==============================] - 0s 132us/sample - loss: 13.9586 - y1_output_loss: 5.0184 - y2_output_loss: 8.9088 - y1_output_root_mean_squared_error: 2.2468 - y2_output_root_mean_squared_error: 2.9850 - val_loss: 16.4109 - val_y1_output_loss: 6.9789 - val_y2_output_loss: 11.1172 - val_y1_output_root_mean_squared_error: 2.5510 - val_y2_output_root_mean_squared_error: 3.1470
# Epoch 32/500
# 614/614 [==============================] - 0s 130us/sample - loss: 14.0193 - y1_output_loss: 5.2404 - y2_output_loss: 8.9657 - y1_output_root_mean_squared_error: 2.2814 - y2_output_root_mean_squared_error: 2.9689 - val_loss: 16.1830 - val_y1_output_loss: 5.1850 - val_y2_output_loss: 11.2889 - val_y1_output_root_mean_squared_error: 2.2764 - val_y2_output_root_mean_squared_error: 3.3168
# Epoch 33/500
# 614/614 [==============================] - 0s 128us/sample - loss: 12.7407 - y1_output_loss: 4.6096 - y2_output_loss: 8.0740 - y1_output_root_mean_squared_error: 2.1534 - y2_output_root_mean_squared_error: 2.8467 - val_loss: 12.5127 - val_y1_output_loss: 5.1785 - val_y2_output_loss: 7.7808 - val_y1_output_root_mean_squared_error: 2.2739 - val_y2_output_root_mean_squared_error: 2.7097
# Epoch 34/500
# 614/614 [==============================] - 0s 126us/sample - loss: 11.8220 - y1_output_loss: 4.3580 - y2_output_loss: 7.4137 - y1_output_root_mean_squared_error: 2.0956 - y2_output_root_mean_squared_error: 2.7259 - val_loss: 17.4660 - val_y1_output_loss: 5.2613 - val_y2_output_loss: 11.9996 - val_y1_output_root_mean_squared_error: 2.3170 - val_y2_output_root_mean_squared_error: 3.4782
# Epoch 35/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.2252 - y1_output_loss: 4.1550 - y2_output_loss: 7.0749 - y1_output_root_mean_squared_error: 2.0212 - y2_output_root_mean_squared_error: 2.6721 - val_loss: 13.4249 - val_y1_output_loss: 4.6112 - val_y2_output_loss: 9.6916 - val_y1_output_root_mean_squared_error: 2.1143 - val_y2_output_root_mean_squared_error: 2.9924
# Epoch 36/500
# 614/614 [==============================] - 0s 134us/sample - loss: 12.2265 - y1_output_loss: 3.9644 - y2_output_loss: 8.1917 - y1_output_root_mean_squared_error: 1.9949 - y2_output_root_mean_squared_error: 2.8717 - val_loss: 10.3821 - val_y1_output_loss: 3.8716 - val_y2_output_loss: 6.5934 - val_y1_output_root_mean_squared_error: 1.9796 - val_y2_output_root_mean_squared_error: 2.5423
# Epoch 37/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.9261 - y1_output_loss: 3.4323 - y2_output_loss: 6.4280 - y1_output_root_mean_squared_error: 1.8593 - y2_output_root_mean_squared_error: 2.5434 - val_loss: 9.2977 - val_y1_output_loss: 3.5564 - val_y2_output_loss: 6.1956 - val_y1_output_root_mean_squared_error: 1.8736 - val_y2_output_root_mean_squared_error: 2.4057
# Epoch 38/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.7281 - y1_output_loss: 3.5546 - y2_output_loss: 6.2335 - y1_output_root_mean_squared_error: 1.8842 - y2_output_root_mean_squared_error: 2.4856 - val_loss: 24.2968 - val_y1_output_loss: 8.0449 - val_y2_output_loss: 16.6455 - val_y1_output_root_mean_squared_error: 2.8233 - val_y2_output_root_mean_squared_error: 4.0405
# Epoch 39/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.3769 - y1_output_loss: 3.3071 - y2_output_loss: 5.9976 - y1_output_root_mean_squared_error: 1.8262 - y2_output_root_mean_squared_error: 2.4580 - val_loss: 13.3015 - val_y1_output_loss: 5.2950 - val_y2_output_loss: 7.7557 - val_y1_output_root_mean_squared_error: 2.3365 - val_y2_output_root_mean_squared_error: 2.8004
# Epoch 40/500
# 614/614 [==============================] - 0s 138us/sample - loss: 11.3275 - y1_output_loss: 3.8057 - y2_output_loss: 7.6488 - y1_output_root_mean_squared_error: 1.9387 - y2_output_root_mean_squared_error: 2.7512 - val_loss: 25.1419 - val_y1_output_loss: 7.5539 - val_y2_output_loss: 17.1637 - val_y1_output_root_mean_squared_error: 2.7800 - val_y2_output_root_mean_squared_error: 4.1729
# Epoch 41/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.6628 - y1_output_loss: 3.5237 - y2_output_loss: 7.1438 - y1_output_root_mean_squared_error: 1.8653 - y2_output_root_mean_squared_error: 2.6802 - val_loss: 11.1672 - val_y1_output_loss: 4.5455 - val_y2_output_loss: 7.1500 - val_y1_output_root_mean_squared_error: 2.1096 - val_y2_output_root_mean_squared_error: 2.5917
# Epoch 42/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.5475 - y1_output_loss: 2.9208 - y2_output_loss: 5.5624 - y1_output_root_mean_squared_error: 1.7145 - y2_output_root_mean_squared_error: 2.3681 - val_loss: 7.8463 - val_y1_output_loss: 2.7460 - val_y2_output_loss: 5.3561 - val_y1_output_root_mean_squared_error: 1.6581 - val_y2_output_root_mean_squared_error: 2.2577
# Epoch 43/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.7658 - y1_output_loss: 2.7602 - y2_output_loss: 4.9499 - y1_output_root_mean_squared_error: 1.6668 - y2_output_root_mean_squared_error: 2.2333 - val_loss: 8.9324 - val_y1_output_loss: 3.1319 - val_y2_output_loss: 6.4185 - val_y1_output_root_mean_squared_error: 1.7398 - val_y2_output_root_mean_squared_error: 2.4301
# Epoch 44/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.1849 - y1_output_loss: 2.7264 - y2_output_loss: 5.4941 - y1_output_root_mean_squared_error: 1.6546 - y2_output_root_mean_squared_error: 2.3339 - val_loss: 12.4763 - val_y1_output_loss: 3.4675 - val_y2_output_loss: 8.9437 - val_y1_output_root_mean_squared_error: 1.8746 - val_y2_output_root_mean_squared_error: 2.9937
# Epoch 45/500
# 614/614 [==============================] - 0s 134us/sample - loss: 9.3189 - y1_output_loss: 2.9030 - y2_output_loss: 6.3596 - y1_output_root_mean_squared_error: 1.7081 - y2_output_root_mean_squared_error: 2.5301 - val_loss: 8.1351 - val_y1_output_loss: 2.7194 - val_y2_output_loss: 5.5820 - val_y1_output_root_mean_squared_error: 1.6690 - val_y2_output_root_mean_squared_error: 2.3129
# Epoch 46/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.8469 - y1_output_loss: 2.3417 - y2_output_loss: 4.4701 - y1_output_root_mean_squared_error: 1.5308 - y2_output_root_mean_squared_error: 2.1221 - val_loss: 7.5342 - val_y1_output_loss: 2.8510 - val_y2_output_loss: 4.8261 - val_y1_output_root_mean_squared_error: 1.7097 - val_y2_output_root_mean_squared_error: 2.1473
# Epoch 47/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.0578 - y1_output_loss: 2.6228 - y2_output_loss: 5.4974 - y1_output_root_mean_squared_error: 1.6000 - y2_output_root_mean_squared_error: 2.3448 - val_loss: 7.3240 - val_y1_output_loss: 2.3818 - val_y2_output_loss: 5.1618 - val_y1_output_root_mean_squared_error: 1.5494 - val_y2_output_root_mean_squared_error: 2.2189
# Epoch 48/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.3432 - y1_output_loss: 2.4356 - y2_output_loss: 4.8919 - y1_output_root_mean_squared_error: 1.5657 - y2_output_root_mean_squared_error: 2.2117 - val_loss: 11.5917 - val_y1_output_loss: 2.8378 - val_y2_output_loss: 8.5865 - val_y1_output_root_mean_squared_error: 1.7063 - val_y2_output_root_mean_squared_error: 2.9463
# Epoch 49/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.3261 - y1_output_loss: 2.3596 - y2_output_loss: 4.9420 - y1_output_root_mean_squared_error: 1.5328 - y2_output_root_mean_squared_error: 2.2308 - val_loss: 11.3156 - val_y1_output_loss: 2.2225 - val_y2_output_loss: 9.5803 - val_y1_output_root_mean_squared_error: 1.4936 - val_y2_output_root_mean_squared_error: 3.0141
# Epoch 50/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.5298 - y1_output_loss: 2.2060 - y2_output_loss: 5.3224 - y1_output_root_mean_squared_error: 1.4906 - y2_output_root_mean_squared_error: 2.3039 - val_loss: 7.5698 - val_y1_output_loss: 2.7603 - val_y2_output_loss: 4.7783 - val_y1_output_root_mean_squared_error: 1.6844 - val_y2_output_root_mean_squared_error: 2.1755
# Epoch 51/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.8723 - y1_output_loss: 2.4880 - y2_output_loss: 5.3753 - y1_output_root_mean_squared_error: 1.5760 - y2_output_root_mean_squared_error: 2.3213 - val_loss: 8.4585 - val_y1_output_loss: 3.0863 - val_y2_output_loss: 5.6156 - val_y1_output_root_mean_squared_error: 1.7401 - val_y2_output_root_mean_squared_error: 2.3303
# Epoch 52/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.2667 - y1_output_loss: 2.4907 - y2_output_loss: 5.8970 - y1_output_root_mean_squared_error: 1.5677 - y2_output_root_mean_squared_error: 2.4102 - val_loss: 12.3374 - val_y1_output_loss: 3.0573 - val_y2_output_loss: 9.7063 - val_y1_output_root_mean_squared_error: 1.7463 - val_y2_output_root_mean_squared_error: 3.0476
# Epoch 53/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.3586 - y1_output_loss: 2.4159 - y2_output_loss: 5.9632 - y1_output_root_mean_squared_error: 1.5589 - y2_output_root_mean_squared_error: 2.4348 - val_loss: 18.4889 - val_y1_output_loss: 4.8065 - val_y2_output_loss: 13.3954 - val_y1_output_root_mean_squared_error: 2.2224 - val_y2_output_root_mean_squared_error: 3.6810
# Epoch 54/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.2943 - y1_output_loss: 1.8854 - y2_output_loss: 4.6143 - y1_output_root_mean_squared_error: 1.3439 - y2_output_root_mean_squared_error: 2.1185 - val_loss: 14.1905 - val_y1_output_loss: 4.7709 - val_y2_output_loss: 9.5706 - val_y1_output_root_mean_squared_error: 2.1966 - val_y2_output_root_mean_squared_error: 3.0603
# Epoch 55/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.7905 - y1_output_loss: 2.0049 - y2_output_loss: 4.7579 - y1_output_root_mean_squared_error: 1.4176 - y2_output_root_mean_squared_error: 2.1865 - val_loss: 7.9654 - val_y1_output_loss: 1.7976 - val_y2_output_loss: 6.2912 - val_y1_output_root_mean_squared_error: 1.3436 - val_y2_output_root_mean_squared_error: 2.4820
# Epoch 56/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.5543 - y1_output_loss: 1.6161 - y2_output_loss: 3.9978 - y1_output_root_mean_squared_error: 1.2721 - y2_output_root_mean_squared_error: 1.9839 - val_loss: 11.6941 - val_y1_output_loss: 1.8450 - val_y2_output_loss: 10.5001 - val_y1_output_root_mean_squared_error: 1.3452 - val_y2_output_root_mean_squared_error: 3.1440
# Epoch 57/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.3409 - y1_output_loss: 1.7040 - y2_output_loss: 4.6759 - y1_output_root_mean_squared_error: 1.3050 - y2_output_root_mean_squared_error: 2.1536 - val_loss: 8.5386 - val_y1_output_loss: 2.7226 - val_y2_output_loss: 5.7592 - val_y1_output_root_mean_squared_error: 1.6705 - val_y2_output_root_mean_squared_error: 2.3975
# Epoch 58/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.0074 - y1_output_loss: 1.4455 - y2_output_loss: 3.6164 - y1_output_root_mean_squared_error: 1.2057 - y2_output_root_mean_squared_error: 1.8851 - val_loss: 11.5618 - val_y1_output_loss: 2.0588 - val_y2_output_loss: 9.9983 - val_y1_output_root_mean_squared_error: 1.4007 - val_y2_output_root_mean_squared_error: 3.0984
# Epoch 59/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.1355 - y1_output_loss: 1.6735 - y2_output_loss: 4.4517 - y1_output_root_mean_squared_error: 1.2969 - y2_output_root_mean_squared_error: 2.1104 - val_loss: 9.2687 - val_y1_output_loss: 2.1670 - val_y2_output_loss: 7.1746 - val_y1_output_root_mean_squared_error: 1.4675 - val_y2_output_root_mean_squared_error: 2.6674
# Epoch 60/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.1573 - y1_output_loss: 1.3323 - y2_output_loss: 3.9913 - y1_output_root_mean_squared_error: 1.1395 - y2_output_root_mean_squared_error: 1.9644 - val_loss: 20.5928 - val_y1_output_loss: 6.3446 - val_y2_output_loss: 14.5382 - val_y1_output_root_mean_squared_error: 2.5352 - val_y2_output_root_mean_squared_error: 3.7637
# Epoch 61/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.6257 - y1_output_loss: 2.6306 - y2_output_loss: 7.0167 - y1_output_root_mean_squared_error: 1.6257 - y2_output_root_mean_squared_error: 2.6425 - val_loss: 8.1639 - val_y1_output_loss: 2.0523 - val_y2_output_loss: 6.1149 - val_y1_output_root_mean_squared_error: 1.4463 - val_y2_output_root_mean_squared_error: 2.4642
# Epoch 62/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.0438 - y1_output_loss: 1.4173 - y2_output_loss: 3.6993 - y1_output_root_mean_squared_error: 1.1753 - y2_output_root_mean_squared_error: 1.9138 - val_loss: 10.2516 - val_y1_output_loss: 2.1443 - val_y2_output_loss: 8.2994 - val_y1_output_root_mean_squared_error: 1.4778 - val_y2_output_root_mean_squared_error: 2.8404
# Epoch 63/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.2237 - y1_output_loss: 1.7990 - y2_output_loss: 4.4181 - y1_output_root_mean_squared_error: 1.3449 - y2_output_root_mean_squared_error: 2.1012 - val_loss: 14.0757 - val_y1_output_loss: 3.0119 - val_y2_output_loss: 11.1323 - val_y1_output_root_mean_squared_error: 1.7337 - val_y2_output_root_mean_squared_error: 3.3272
# Epoch 64/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.4021 - y1_output_loss: 1.4811 - y2_output_loss: 3.8694 - y1_output_root_mean_squared_error: 1.2229 - y2_output_root_mean_squared_error: 1.9765 - val_loss: 4.0502 - val_y1_output_loss: 1.0237 - val_y2_output_loss: 3.1253 - val_y1_output_root_mean_squared_error: 1.0090 - val_y2_output_root_mean_squared_error: 1.7413
# Epoch 65/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.3569 - y1_output_loss: 1.1924 - y2_output_loss: 4.1597 - y1_output_root_mean_squared_error: 1.0930 - y2_output_root_mean_squared_error: 2.0401 - val_loss: 9.0264 - val_y1_output_loss: 2.0956 - val_y2_output_loss: 7.7040 - val_y1_output_root_mean_squared_error: 1.4007 - val_y2_output_root_mean_squared_error: 2.6579
# Epoch 66/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.4073 - y1_output_loss: 1.3342 - y2_output_loss: 4.0419 - y1_output_root_mean_squared_error: 1.1590 - y2_output_root_mean_squared_error: 2.0159 - val_loss: 5.2753 - val_y1_output_loss: 1.5373 - val_y2_output_loss: 3.8526 - val_y1_output_root_mean_squared_error: 1.2499 - val_y2_output_root_mean_squared_error: 1.9269
# Epoch 67/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.5749 - y1_output_loss: 1.5170 - y2_output_loss: 4.0413 - y1_output_root_mean_squared_error: 1.2270 - y2_output_root_mean_squared_error: 2.0173 - val_loss: 7.3288 - val_y1_output_loss: 0.9922 - val_y2_output_loss: 6.8147 - val_y1_output_root_mean_squared_error: 0.9917 - val_y2_output_root_mean_squared_error: 2.5190
# Epoch 68/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.2335 - y1_output_loss: 1.0345 - y2_output_loss: 3.1811 - y1_output_root_mean_squared_error: 1.0186 - y2_output_root_mean_squared_error: 1.7877 - val_loss: 6.9815 - val_y1_output_loss: 1.7893 - val_y2_output_loss: 5.1905 - val_y1_output_root_mean_squared_error: 1.3444 - val_y2_output_root_mean_squared_error: 2.2746
# Epoch 69/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.9744 - y1_output_loss: 1.2497 - y2_output_loss: 3.7182 - y1_output_root_mean_squared_error: 1.1075 - y2_output_root_mean_squared_error: 1.9359 - val_loss: 4.6176 - val_y1_output_loss: 1.3580 - val_y2_output_loss: 3.4188 - val_y1_output_root_mean_squared_error: 1.1803 - val_y2_output_root_mean_squared_error: 1.7957
# Epoch 70/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.9219 - y1_output_loss: 0.9291 - y2_output_loss: 3.0238 - y1_output_root_mean_squared_error: 0.9596 - y2_output_root_mean_squared_error: 1.7324 - val_loss: 6.5220 - val_y1_output_loss: 1.2824 - val_y2_output_loss: 5.3195 - val_y1_output_root_mean_squared_error: 1.1299 - val_y2_output_root_mean_squared_error: 2.2903
# Epoch 71/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.1019 - y1_output_loss: 1.0566 - y2_output_loss: 4.0028 - y1_output_root_mean_squared_error: 1.0322 - y2_output_root_mean_squared_error: 2.0091 - val_loss: 4.8097 - val_y1_output_loss: 1.0488 - val_y2_output_loss: 3.9440 - val_y1_output_root_mean_squared_error: 1.0233 - val_y2_output_root_mean_squared_error: 1.9397
# Epoch 72/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.6496 - y1_output_loss: 1.0766 - y2_output_loss: 3.5527 - y1_output_root_mean_squared_error: 1.0422 - y2_output_root_mean_squared_error: 1.8877 - val_loss: 4.7911 - val_y1_output_loss: 1.6321 - val_y2_output_loss: 3.2933 - val_y1_output_root_mean_squared_error: 1.2785 - val_y2_output_root_mean_squared_error: 1.7767
# Epoch 73/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.7944 - y1_output_loss: 0.9775 - y2_output_loss: 2.8397 - y1_output_root_mean_squared_error: 0.9859 - y2_output_root_mean_squared_error: 1.6800 - val_loss: 11.1213 - val_y1_output_loss: 2.4168 - val_y2_output_loss: 9.2726 - val_y1_output_root_mean_squared_error: 1.4968 - val_y2_output_root_mean_squared_error: 2.9801
# Epoch 74/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.4556 - y1_output_loss: 1.3430 - y2_output_loss: 4.0882 - y1_output_root_mean_squared_error: 1.1620 - y2_output_root_mean_squared_error: 2.0262 - val_loss: 6.9815 - val_y1_output_loss: 0.7309 - val_y2_output_loss: 6.6303 - val_y1_output_root_mean_squared_error: 0.8573 - val_y2_output_root_mean_squared_error: 2.4993
# Epoch 75/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.7432 - y1_output_loss: 1.0821 - y2_output_loss: 3.7264 - y1_output_root_mean_squared_error: 1.0444 - y2_output_root_mean_squared_error: 1.9111 - val_loss: 11.9169 - val_y1_output_loss: 1.5601 - val_y2_output_loss: 11.1888 - val_y1_output_root_mean_squared_error: 1.2226 - val_y2_output_root_mean_squared_error: 3.2283
# Epoch 76/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.8770 - y1_output_loss: 1.1811 - y2_output_loss: 3.6635 - y1_output_root_mean_squared_error: 1.0868 - y2_output_root_mean_squared_error: 1.9224 - val_loss: 3.4748 - val_y1_output_loss: 0.9283 - val_y2_output_loss: 2.7008 - val_y1_output_root_mean_squared_error: 0.9473 - val_y2_output_root_mean_squared_error: 1.6054
# Epoch 77/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.6708 - y1_output_loss: 1.2354 - y2_output_loss: 3.4274 - y1_output_root_mean_squared_error: 1.1113 - y2_output_root_mean_squared_error: 1.8536 - val_loss: 6.0556 - val_y1_output_loss: 0.9584 - val_y2_output_loss: 5.2807 - val_y1_output_root_mean_squared_error: 0.9906 - val_y2_output_root_mean_squared_error: 2.2526
# Epoch 78/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.7804 - y1_output_loss: 1.0349 - y2_output_loss: 2.9795 - y1_output_root_mean_squared_error: 0.9727 - y2_output_root_mean_squared_error: 1.6835 - val_loss: 38.3493 - val_y1_output_loss: 11.8388 - val_y2_output_loss: 26.9169 - val_y1_output_root_mean_squared_error: 3.4194 - val_y2_output_root_mean_squared_error: 5.1631
# Epoch 79/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.7558 - y1_output_loss: 1.5655 - y2_output_loss: 4.1509 - y1_output_root_mean_squared_error: 1.2560 - y2_output_root_mean_squared_error: 2.0441 - val_loss: 5.1757 - val_y1_output_loss: 1.4277 - val_y2_output_loss: 3.7991 - val_y1_output_root_mean_squared_error: 1.2038 - val_y2_output_root_mean_squared_error: 1.9304
# Epoch 80/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.3161 - y1_output_loss: 0.7487 - y2_output_loss: 2.6211 - y1_output_root_mean_squared_error: 0.8689 - y2_output_root_mean_squared_error: 1.6003 - val_loss: 26.6793 - val_y1_output_loss: 3.0446 - val_y2_output_loss: 24.1900 - val_y1_output_root_mean_squared_error: 1.7332 - val_y2_output_root_mean_squared_error: 4.8657
# Epoch 81/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.2265 - y1_output_loss: 1.4846 - y2_output_loss: 4.7698 - y1_output_root_mean_squared_error: 1.2235 - y2_output_root_mean_squared_error: 2.1747 - val_loss: 5.1686 - val_y1_output_loss: 0.9172 - val_y2_output_loss: 4.3705 - val_y1_output_root_mean_squared_error: 0.9476 - val_y2_output_root_mean_squared_error: 2.0666
# Epoch 82/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.8268 - y1_output_loss: 0.7980 - y2_output_loss: 3.0239 - y1_output_root_mean_squared_error: 0.8957 - y2_output_root_mean_squared_error: 1.7391 - val_loss: 3.7847 - val_y1_output_loss: 1.0456 - val_y2_output_loss: 2.9808 - val_y1_output_root_mean_squared_error: 0.9929 - val_y2_output_root_mean_squared_error: 1.6729
# Epoch 83/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.5949 - y1_output_loss: 1.5103 - y2_output_loss: 4.1544 - y1_output_root_mean_squared_error: 1.2169 - y2_output_root_mean_squared_error: 2.0283 - val_loss: 17.7569 - val_y1_output_loss: 6.2370 - val_y2_output_loss: 13.0718 - val_y1_output_root_mean_squared_error: 2.3718 - val_y2_output_root_mean_squared_error: 3.4830
# Epoch 84/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.8582 - y1_output_loss: 0.9709 - y2_output_loss: 2.9192 - y1_output_root_mean_squared_error: 0.9883 - y2_output_root_mean_squared_error: 1.6975 - val_loss: 5.2708 - val_y1_output_loss: 1.0583 - val_y2_output_loss: 4.2510 - val_y1_output_root_mean_squared_error: 1.0213 - val_y2_output_root_mean_squared_error: 2.0561
# Epoch 85/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.7816 - y1_output_loss: 0.8365 - y2_output_loss: 2.9390 - y1_output_root_mean_squared_error: 0.9145 - y2_output_root_mean_squared_error: 1.7162 - val_loss: 5.8482 - val_y1_output_loss: 1.1206 - val_y2_output_loss: 4.9341 - val_y1_output_root_mean_squared_error: 1.0603 - val_y2_output_root_mean_squared_error: 2.1735
# Epoch 86/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.2759 - y1_output_loss: 0.8220 - y2_output_loss: 2.4480 - y1_output_root_mean_squared_error: 0.9099 - y2_output_root_mean_squared_error: 1.5646 - val_loss: 3.5961 - val_y1_output_loss: 0.8900 - val_y2_output_loss: 2.7347 - val_y1_output_root_mean_squared_error: 0.9553 - val_y2_output_root_mean_squared_error: 1.6381
# Epoch 87/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.0293 - y1_output_loss: 0.7046 - y2_output_loss: 2.3217 - y1_output_root_mean_squared_error: 0.8379 - y2_output_root_mean_squared_error: 1.5255 - val_loss: 3.3047 - val_y1_output_loss: 0.7282 - val_y2_output_loss: 2.6868 - val_y1_output_root_mean_squared_error: 0.8577 - val_y2_output_root_mean_squared_error: 1.6028
# Epoch 88/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.6862 - y1_output_loss: 0.7590 - y2_output_loss: 3.0201 - y1_output_root_mean_squared_error: 0.8662 - y2_output_root_mean_squared_error: 1.7134 - val_loss: 12.4172 - val_y1_output_loss: 4.8065 - val_y2_output_loss: 8.0389 - val_y1_output_root_mean_squared_error: 2.1734 - val_y2_output_root_mean_squared_error: 2.7737
# Epoch 89/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.4506 - y1_output_loss: 0.8709 - y2_output_loss: 2.5733 - y1_output_root_mean_squared_error: 0.9344 - y2_output_root_mean_squared_error: 1.6054 - val_loss: 2.7653 - val_y1_output_loss: 0.5459 - val_y2_output_loss: 2.2699 - val_y1_output_root_mean_squared_error: 0.7453 - val_y2_output_root_mean_squared_error: 1.4865
# Epoch 90/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.0268 - y1_output_loss: 1.2435 - y2_output_loss: 3.7843 - y1_output_root_mean_squared_error: 1.1176 - y2_output_root_mean_squared_error: 1.9437 - val_loss: 3.9998 - val_y1_output_loss: 1.0898 - val_y2_output_loss: 2.9507 - val_y1_output_root_mean_squared_error: 1.0401 - val_y2_output_root_mean_squared_error: 1.7082
# Epoch 91/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.9459 - y1_output_loss: 0.6650 - y2_output_loss: 2.2912 - y1_output_root_mean_squared_error: 0.8103 - y2_output_root_mean_squared_error: 1.5130 - val_loss: 3.2118 - val_y1_output_loss: 0.7561 - val_y2_output_loss: 2.5506 - val_y1_output_root_mean_squared_error: 0.8740 - val_y2_output_root_mean_squared_error: 1.5646
# Epoch 92/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.2776 - y1_output_loss: 0.7899 - y2_output_loss: 2.4716 - y1_output_root_mean_squared_error: 0.8893 - y2_output_root_mean_squared_error: 1.5769 - val_loss: 4.3051 - val_y1_output_loss: 1.5962 - val_y2_output_loss: 2.7677 - val_y1_output_root_mean_squared_error: 1.2714 - val_y2_output_root_mean_squared_error: 1.6397
# Epoch 93/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.7360 - y1_output_loss: 0.8237 - y2_output_loss: 2.8800 - y1_output_root_mean_squared_error: 0.9107 - y2_output_root_mean_squared_error: 1.7049 - val_loss: 4.6597 - val_y1_output_loss: 1.0080 - val_y2_output_loss: 3.7764 - val_y1_output_root_mean_squared_error: 0.9997 - val_y2_output_root_mean_squared_error: 1.9132
# Epoch 94/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.0932 - y1_output_loss: 0.6478 - y2_output_loss: 2.4773 - y1_output_root_mean_squared_error: 0.8054 - y2_output_root_mean_squared_error: 1.5635 - val_loss: 8.4591 - val_y1_output_loss: 1.4527 - val_y2_output_loss: 6.9467 - val_y1_output_root_mean_squared_error: 1.2234 - val_y2_output_root_mean_squared_error: 2.6386
# Epoch 95/500
# 614/614 [==============================] - 0s 126us/sample - loss: 9.2354 - y1_output_loss: 2.2435 - y2_output_loss: 6.9638 - y1_output_root_mean_squared_error: 1.5042 - y2_output_root_mean_squared_error: 2.6406 - val_loss: 8.6469 - val_y1_output_loss: 1.6685 - val_y2_output_loss: 7.2642 - val_y1_output_root_mean_squared_error: 1.2628 - val_y2_output_root_mean_squared_error: 2.6556
# Epoch 96/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.5875 - y1_output_loss: 1.0192 - y2_output_loss: 3.5270 - y1_output_root_mean_squared_error: 1.0143 - y2_output_root_mean_squared_error: 1.8864 - val_loss: 2.6404 - val_y1_output_loss: 0.5729 - val_y2_output_loss: 2.2554 - val_y1_output_root_mean_squared_error: 0.7548 - val_y2_output_root_mean_squared_error: 1.4390
# Epoch 97/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.4521 - y1_output_loss: 0.7271 - y2_output_loss: 2.7444 - y1_output_root_mean_squared_error: 0.8529 - y2_output_root_mean_squared_error: 1.6506 - val_loss: 4.3467 - val_y1_output_loss: 0.7977 - val_y2_output_loss: 3.6859 - val_y1_output_root_mean_squared_error: 0.9040 - val_y2_output_root_mean_squared_error: 1.8787
# Epoch 98/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.3152 - y1_output_loss: 0.7995 - y2_output_loss: 2.5132 - y1_output_root_mean_squared_error: 0.8871 - y2_output_root_mean_squared_error: 1.5900 - val_loss: 4.1068 - val_y1_output_loss: 1.3050 - val_y2_output_loss: 3.0602 - val_y1_output_root_mean_squared_error: 1.1235 - val_y2_output_root_mean_squared_error: 1.6866
# Epoch 99/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.6531 - y1_output_loss: 0.7823 - y2_output_loss: 2.8489 - y1_output_root_mean_squared_error: 0.8883 - y2_output_root_mean_squared_error: 1.6923 - val_loss: 3.5266 - val_y1_output_loss: 0.7916 - val_y2_output_loss: 2.7395 - val_y1_output_root_mean_squared_error: 0.8950 - val_y2_output_root_mean_squared_error: 1.6509
# Epoch 100/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.7140 - y1_output_loss: 0.6113 - y2_output_loss: 2.0879 - y1_output_root_mean_squared_error: 0.7816 - y2_output_root_mean_squared_error: 1.4502 - val_loss: 4.4856 - val_y1_output_loss: 1.2206 - val_y2_output_loss: 3.4329 - val_y1_output_root_mean_squared_error: 1.0976 - val_y2_output_root_mean_squared_error: 1.8113
# Epoch 101/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.9114 - y1_output_loss: 0.5945 - y2_output_loss: 2.3398 - y1_output_root_mean_squared_error: 0.7578 - y2_output_root_mean_squared_error: 1.5288 - val_loss: 3.5730 - val_y1_output_loss: 1.2931 - val_y2_output_loss: 2.5250 - val_y1_output_root_mean_squared_error: 1.1085 - val_y2_output_root_mean_squared_error: 1.5311
# Epoch 102/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.0257 - y1_output_loss: 0.6514 - y2_output_loss: 2.3637 - y1_output_root_mean_squared_error: 0.8100 - y2_output_root_mean_squared_error: 1.5393 - val_loss: 3.0362 - val_y1_output_loss: 0.7270 - val_y2_output_loss: 2.3524 - val_y1_output_root_mean_squared_error: 0.8565 - val_y2_output_root_mean_squared_error: 1.5174
# Epoch 103/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.1851 - y1_output_loss: 0.7182 - y2_output_loss: 2.4747 - y1_output_root_mean_squared_error: 0.8502 - y2_output_root_mean_squared_error: 1.5692 - val_loss: 4.9737 - val_y1_output_loss: 0.7004 - val_y2_output_loss: 4.4651 - val_y1_output_root_mean_squared_error: 0.8408 - val_y2_output_root_mean_squared_error: 2.0656
# Epoch 104/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.9237 - y1_output_loss: 0.6378 - y2_output_loss: 2.2851 - y1_output_root_mean_squared_error: 0.7999 - y2_output_root_mean_squared_error: 1.5112 - val_loss: 4.2567 - val_y1_output_loss: 1.1906 - val_y2_output_loss: 3.4052 - val_y1_output_root_mean_squared_error: 1.0548 - val_y2_output_root_mean_squared_error: 1.7731
# Epoch 105/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.0782 - y1_output_loss: 1.7083 - y2_output_loss: 5.3193 - y1_output_root_mean_squared_error: 1.3114 - y2_output_root_mean_squared_error: 2.3148 - val_loss: 2.9198 - val_y1_output_loss: 0.6599 - val_y2_output_loss: 2.3286 - val_y1_output_root_mean_squared_error: 0.8179 - val_y2_output_root_mean_squared_error: 1.5003
# Epoch 106/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.8844 - y1_output_loss: 0.6558 - y2_output_loss: 2.2342 - y1_output_root_mean_squared_error: 0.8073 - y2_output_root_mean_squared_error: 1.4942 - val_loss: 2.9479 - val_y1_output_loss: 0.8784 - val_y2_output_loss: 2.2482 - val_y1_output_root_mean_squared_error: 0.9203 - val_y2_output_root_mean_squared_error: 1.4495
# Epoch 107/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.9860 - y1_output_loss: 0.6229 - y2_output_loss: 2.3894 - y1_output_root_mean_squared_error: 0.7903 - y2_output_root_mean_squared_error: 1.5367 - val_loss: 10.4374 - val_y1_output_loss: 1.4646 - val_y2_output_loss: 8.9953 - val_y1_output_root_mean_squared_error: 1.2212 - val_y2_output_root_mean_squared_error: 2.9910
# Epoch 108/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.7654 - y1_output_loss: 0.8900 - y2_output_loss: 2.8429 - y1_output_root_mean_squared_error: 0.9473 - y2_output_root_mean_squared_error: 1.6935 - val_loss: 3.0113 - val_y1_output_loss: 0.5703 - val_y2_output_loss: 2.6340 - val_y1_output_root_mean_squared_error: 0.7631 - val_y2_output_root_mean_squared_error: 1.5585
# Epoch 109/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.5910 - y1_output_loss: 0.5654 - y2_output_loss: 2.0143 - y1_output_root_mean_squared_error: 0.7490 - y2_output_root_mean_squared_error: 1.4248 - val_loss: 2.4620 - val_y1_output_loss: 0.5980 - val_y2_output_loss: 1.9888 - val_y1_output_root_mean_squared_error: 0.7722 - val_y2_output_root_mean_squared_error: 1.3659
# Epoch 110/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.7197 - y1_output_loss: 0.5451 - y2_output_loss: 2.1973 - y1_output_root_mean_squared_error: 0.7411 - y2_output_root_mean_squared_error: 1.4732 - val_loss: 3.0531 - val_y1_output_loss: 0.6369 - val_y2_output_loss: 2.5381 - val_y1_output_root_mean_squared_error: 0.7929 - val_y2_output_root_mean_squared_error: 1.5570
# Epoch 111/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.5791 - y1_output_loss: 0.6001 - y2_output_loss: 1.9779 - y1_output_root_mean_squared_error: 0.7761 - y2_output_root_mean_squared_error: 1.4060 - val_loss: 2.5561 - val_y1_output_loss: 0.6412 - val_y2_output_loss: 1.9737 - val_y1_output_root_mean_squared_error: 0.7993 - val_y2_output_root_mean_squared_error: 1.3846
# Epoch 112/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.8022 - y1_output_loss: 0.7136 - y2_output_loss: 2.0995 - y1_output_root_mean_squared_error: 0.8442 - y2_output_root_mean_squared_error: 1.4455 - val_loss: 4.3396 - val_y1_output_loss: 0.6621 - val_y2_output_loss: 3.8202 - val_y1_output_root_mean_squared_error: 0.8143 - val_y2_output_root_mean_squared_error: 1.9174
# Epoch 113/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.5930 - y1_output_loss: 0.6327 - y2_output_loss: 1.9444 - y1_output_root_mean_squared_error: 0.7985 - y2_output_root_mean_squared_error: 1.3983 - val_loss: 2.8048 - val_y1_output_loss: 0.7068 - val_y2_output_loss: 2.1963 - val_y1_output_root_mean_squared_error: 0.8347 - val_y2_output_root_mean_squared_error: 1.4519
# Epoch 114/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.3324 - y1_output_loss: 0.7675 - y2_output_loss: 2.5760 - y1_output_root_mean_squared_error: 0.8774 - y2_output_root_mean_squared_error: 1.6008 - val_loss: 3.0077 - val_y1_output_loss: 0.6352 - val_y2_output_loss: 2.6067 - val_y1_output_root_mean_squared_error: 0.7970 - val_y2_output_root_mean_squared_error: 1.5403
# Epoch 115/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.9071 - y1_output_loss: 0.6442 - y2_output_loss: 2.2409 - y1_output_root_mean_squared_error: 0.8065 - y2_output_root_mean_squared_error: 1.5022 - val_loss: 3.8982 - val_y1_output_loss: 0.5048 - val_y2_output_loss: 3.4408 - val_y1_output_root_mean_squared_error: 0.7081 - val_y2_output_root_mean_squared_error: 1.8430
# Epoch 116/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.4979 - y1_output_loss: 0.6015 - y2_output_loss: 1.9037 - y1_output_root_mean_squared_error: 0.7768 - y2_output_root_mean_squared_error: 1.3764 - val_loss: 4.1774 - val_y1_output_loss: 1.3853 - val_y2_output_loss: 2.8578 - val_y1_output_root_mean_squared_error: 1.1734 - val_y2_output_root_mean_squared_error: 1.6735
# Epoch 117/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.8472 - y1_output_loss: 0.8009 - y2_output_loss: 3.0630 - y1_output_root_mean_squared_error: 0.8973 - y2_output_root_mean_squared_error: 1.7441 - val_loss: 8.0312 - val_y1_output_loss: 1.3957 - val_y2_output_loss: 6.4949 - val_y1_output_root_mean_squared_error: 1.1935 - val_y2_output_root_mean_squared_error: 2.5704
# Epoch 118/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.4165 - y1_output_loss: 0.7669 - y2_output_loss: 2.6322 - y1_output_root_mean_squared_error: 0.8799 - y2_output_root_mean_squared_error: 1.6255 - val_loss: 3.2613 - val_y1_output_loss: 0.8212 - val_y2_output_loss: 2.5157 - val_y1_output_root_mean_squared_error: 0.9118 - val_y2_output_root_mean_squared_error: 1.5588
# Epoch 119/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.7976 - y1_output_loss: 0.5337 - y2_output_loss: 2.2523 - y1_output_root_mean_squared_error: 0.7303 - y2_output_root_mean_squared_error: 1.5048 - val_loss: 3.2926 - val_y1_output_loss: 0.8211 - val_y2_output_loss: 2.6282 - val_y1_output_root_mean_squared_error: 0.8878 - val_y2_output_root_mean_squared_error: 1.5825
# Epoch 120/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.1887 - y1_output_loss: 0.7992 - y2_output_loss: 2.3666 - y1_output_root_mean_squared_error: 0.8970 - y2_output_root_mean_squared_error: 1.5441 - val_loss: 3.4460 - val_y1_output_loss: 0.9987 - val_y2_output_loss: 2.4540 - val_y1_output_root_mean_squared_error: 1.0161 - val_y2_output_root_mean_squared_error: 1.5536
# ...
# Epoch 326/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.6030 - y1_output_loss: 0.1631 - y2_output_loss: 0.4409 - y1_output_root_mean_squared_error: 0.4042 - y2_output_root_mean_squared_error: 0.6630 - val_loss: 1.0717 - val_y1_output_loss: 0.1873 - val_y2_output_loss: 0.8946 - val_y1_output_root_mean_squared_error: 0.4327 - val_y2_output_root_mean_squared_error: 0.9404
# Epoch 327/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.9978 - y1_output_loss: 0.2070 - y2_output_loss: 0.7864 - y1_output_root_mean_squared_error: 0.4545 - y2_output_root_mean_squared_error: 0.8895 - val_loss: 1.2070 - val_y1_output_loss: 0.2939 - val_y2_output_loss: 0.9167 - val_y1_output_root_mean_squared_error: 0.5432 - val_y2_output_root_mean_squared_error: 0.9550
# Epoch 328/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.6596 - y1_output_loss: 0.1662 - y2_output_loss: 0.4983 - y1_output_root_mean_squared_error: 0.4085 - y2_output_root_mean_squared_error: 0.7019 - val_loss: 1.3596 - val_y1_output_loss: 0.1884 - val_y2_output_loss: 1.1961 - val_y1_output_root_mean_squared_error: 0.4294 - val_y2_output_root_mean_squared_error: 1.0841
# Epoch 329/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.7597 - y1_output_loss: 0.1840 - y2_output_loss: 0.5732 - y1_output_root_mean_squared_error: 0.4284 - y2_output_root_mean_squared_error: 0.7590 - val_loss: 1.5224 - val_y1_output_loss: 0.4093 - val_y2_output_loss: 1.1131 - val_y1_output_root_mean_squared_error: 0.6417 - val_y2_output_root_mean_squared_error: 1.0539
# Epoch 330/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.6632 - y1_output_loss: 0.1578 - y2_output_loss: 0.5633 - y1_output_root_mean_squared_error: 0.3986 - y2_output_root_mean_squared_error: 0.7101 - val_loss: 3.4234 - val_y1_output_loss: 0.3867 - val_y2_output_loss: 3.0547 - val_y1_output_root_mean_squared_error: 0.6184 - val_y2_output_root_mean_squared_error: 1.7438
# Epoch 331/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.9755 - y1_output_loss: 0.2185 - y2_output_loss: 0.7531 - y1_output_root_mean_squared_error: 0.4691 - y2_output_root_mean_squared_error: 0.8691 - val_loss: 0.9239 - val_y1_output_loss: 0.1574 - val_y2_output_loss: 0.8015 - val_y1_output_root_mean_squared_error: 0.3894 - val_y2_output_root_mean_squared_error: 0.8788
# Epoch 332/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.7525 - y1_output_loss: 0.1735 - y2_output_loss: 0.5766 - y1_output_root_mean_squared_error: 0.4162 - y2_output_root_mean_squared_error: 0.7611 - val_loss: 1.2955 - val_y1_output_loss: 0.2403 - val_y2_output_loss: 1.0804 - val_y1_output_root_mean_squared_error: 0.4916 - val_y2_output_root_mean_squared_error: 1.0266
# Epoch 333/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.8589 - y1_output_loss: 0.2048 - y2_output_loss: 0.6472 - y1_output_root_mean_squared_error: 0.4543 - y2_output_root_mean_squared_error: 0.8078 - val_loss: 1.1155 - val_y1_output_loss: 0.1613 - val_y2_output_loss: 0.9560 - val_y1_output_root_mean_squared_error: 0.4029 - val_y2_output_root_mean_squared_error: 0.9763
# Epoch 334/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.7383 - y1_output_loss: 0.1680 - y2_output_loss: 0.5696 - y1_output_root_mean_squared_error: 0.4048 - y2_output_root_mean_squared_error: 0.7579 - val_loss: 1.2931 - val_y1_output_loss: 0.2883 - val_y2_output_loss: 1.0613 - val_y1_output_root_mean_squared_error: 0.5330 - val_y2_output_root_mean_squared_error: 1.0045
# Epoch 335/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.7987 - y1_output_loss: 0.1909 - y2_output_loss: 0.6067 - y1_output_root_mean_squared_error: 0.4379 - y2_output_root_mean_squared_error: 0.7791 - val_loss: 1.6151 - val_y1_output_loss: 0.3552 - val_y2_output_loss: 1.2723 - val_y1_output_root_mean_squared_error: 0.5952 - val_y2_output_root_mean_squared_error: 1.1229
# Epoch 336/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.8274 - y1_output_loss: 0.2006 - y2_output_loss: 0.6320 - y1_output_root_mean_squared_error: 0.4488 - y2_output_root_mean_squared_error: 0.7912 - val_loss: 1.1583 - val_y1_output_loss: 0.1964 - val_y2_output_loss: 0.9600 - val_y1_output_root_mean_squared_error: 0.4463 - val_y2_output_root_mean_squared_error: 0.9793
# Epoch 337/500
# 614/614 [==============================] - 0s 134us/sample - loss: 1.1651 - y1_output_loss: 0.2170 - y2_output_loss: 0.9416 - y1_output_root_mean_squared_error: 0.4656 - y2_output_root_mean_squared_error: 0.9739 - val_loss: 1.1762 - val_y1_output_loss: 0.1907 - val_y2_output_loss: 0.9925 - val_y1_output_root_mean_squared_error: 0.4410 - val_y2_output_root_mean_squared_error: 0.9908
# Epoch 338/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.6641 - y1_output_loss: 0.1785 - y2_output_loss: 0.4959 - y1_output_root_mean_squared_error: 0.4214 - y2_output_root_mean_squared_error: 0.6975 - val_loss: 1.3192 - val_y1_output_loss: 0.2890 - val_y2_output_loss: 1.0341 - val_y1_output_root_mean_squared_error: 0.5432 - val_y2_output_root_mean_squared_error: 1.0120
# Epoch 339/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.8921 - y1_output_loss: 0.1995 - y2_output_loss: 0.6900 - y1_output_root_mean_squared_error: 0.4454 - y2_output_root_mean_squared_error: 0.8329 - val_loss: 0.9516 - val_y1_output_loss: 0.1977 - val_y2_output_loss: 0.7880 - val_y1_output_root_mean_squared_error: 0.4386 - val_y2_output_root_mean_squared_error: 0.8713
# Epoch 340/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.8004 - y1_output_loss: 0.1874 - y2_output_loss: 0.6105 - y1_output_root_mean_squared_error: 0.4339 - y2_output_root_mean_squared_error: 0.7824 - val_loss: 1.2833 - val_y1_output_loss: 0.2473 - val_y2_output_loss: 1.0548 - val_y1_output_root_mean_squared_error: 0.4943 - val_y2_output_root_mean_squared_error: 1.0193
# Epoch 341/500
# 614/614 [==============================] - 0s 128us/sample - loss: 1.0229 - y1_output_loss: 0.2495 - y2_output_loss: 0.7724 - y1_output_root_mean_squared_error: 0.5010 - y2_output_root_mean_squared_error: 0.8786 - val_loss: 1.5002 - val_y1_output_loss: 0.1544 - val_y2_output_loss: 1.3773 - val_y1_output_root_mean_squared_error: 0.3945 - val_y2_output_root_mean_squared_error: 1.1596
# Epoch 342/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.7181 - y1_output_loss: 0.1686 - y2_output_loss: 0.5527 - y1_output_root_mean_squared_error: 0.4062 - y2_output_root_mean_squared_error: 0.7437 - val_loss: 1.2839 - val_y1_output_loss: 0.2717 - val_y2_output_loss: 1.0104 - val_y1_output_root_mean_squared_error: 0.5260 - val_y2_output_root_mean_squared_error: 1.0036
# Epoch 343/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.7732 - y1_output_loss: 0.1721 - y2_output_loss: 0.5949 - y1_output_root_mean_squared_error: 0.4155 - y2_output_root_mean_squared_error: 0.7749 - val_loss: 0.8983 - val_y1_output_loss: 0.1875 - val_y2_output_loss: 0.7106 - val_y1_output_root_mean_squared_error: 0.4342 - val_y2_output_root_mean_squared_error: 0.8424
# Epoch 344/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.7701 - y1_output_loss: 0.1691 - y2_output_loss: 0.5937 - y1_output_root_mean_squared_error: 0.4133 - y2_output_root_mean_squared_error: 0.7741 - val_loss: 0.9081 - val_y1_output_loss: 0.1611 - val_y2_output_loss: 0.7307 - val_y1_output_root_mean_squared_error: 0.4050 - val_y2_output_root_mean_squared_error: 0.8626
# Epoch 345/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.8032 - y1_output_loss: 0.1694 - y2_output_loss: 0.6286 - y1_output_root_mean_squared_error: 0.4135 - y2_output_root_mean_squared_error: 0.7951 - val_loss: 1.1566 - val_y1_output_loss: 0.1729 - val_y2_output_loss: 0.9851 - val_y1_output_root_mean_squared_error: 0.4155 - val_y2_output_root_mean_squared_error: 0.9919
# Epoch 346/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.8538 - y1_output_loss: 0.2001 - y2_output_loss: 0.6529 - y1_output_root_mean_squared_error: 0.4484 - y2_output_root_mean_squared_error: 0.8079 - val_loss: 1.0753 - val_y1_output_loss: 0.1921 - val_y2_output_loss: 0.8827 - val_y1_output_root_mean_squared_error: 0.4413 - val_y2_output_root_mean_squared_error: 0.9384
# Epoch 347/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.7040 - y1_output_loss: 0.1866 - y2_output_loss: 0.5263 - y1_output_root_mean_squared_error: 0.4269 - y2_output_root_mean_squared_error: 0.7223 - val_loss: 3.5319 - val_y1_output_loss: 1.0956 - val_y2_output_loss: 2.6672 - val_y1_output_root_mean_squared_error: 1.0058 - val_y2_output_root_mean_squared_error: 1.5875
# Epoch 348/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.7573 - y1_output_loss: 0.1956 - y2_output_loss: 0.5699 - y1_output_root_mean_squared_error: 0.4426 - y2_output_root_mean_squared_error: 0.7493 - val_loss: 3.8816 - val_y1_output_loss: 0.4064 - val_y2_output_loss: 3.4605 - val_y1_output_root_mean_squared_error: 0.6379 - val_y2_output_root_mean_squared_error: 1.8640
# Epoch 349/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.9693 - y1_output_loss: 0.2303 - y2_output_loss: 0.7423 - y1_output_root_mean_squared_error: 0.4810 - y2_output_root_mean_squared_error: 0.8591 - val_loss: 2.1703 - val_y1_output_loss: 0.1870 - val_y2_output_loss: 1.9883 - val_y1_output_root_mean_squared_error: 0.4361 - val_y2_output_root_mean_squared_error: 1.4072
# Epoch 350/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.9027 - y1_output_loss: 0.1911 - y2_output_loss: 0.7094 - y1_output_root_mean_squared_error: 0.4387 - y2_output_root_mean_squared_error: 0.8428 - val_loss: 1.0993 - val_y1_output_loss: 0.2010 - val_y2_output_loss: 0.8959 - val_y1_output_root_mean_squared_error: 0.4457 - val_y2_output_root_mean_squared_error: 0.9490
# Epoch 351/500
# 614/614 [==============================] - 0s 131us/sample - loss: 1.1440 - y1_output_loss: 0.2505 - y2_output_loss: 0.8938 - y1_output_root_mean_squared_error: 0.4926 - y2_output_root_mean_squared_error: 0.9494 - val_loss: 1.1562 - val_y1_output_loss: 0.3113 - val_y2_output_loss: 0.8331 - val_y1_output_root_mean_squared_error: 0.5634 - val_y2_output_root_mean_squared_error: 0.9158
# Epoch 352/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.6911 - y1_output_loss: 0.1708 - y2_output_loss: 0.5166 - y1_output_root_mean_squared_error: 0.4135 - y2_output_root_mean_squared_error: 0.7211 - val_loss: 1.0043 - val_y1_output_loss: 0.1961 - val_y2_output_loss: 0.8162 - val_y1_output_root_mean_squared_error: 0.4435 - val_y2_output_root_mean_squared_error: 0.8987
# Epoch 353/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.7769 - y1_output_loss: 0.1866 - y2_output_loss: 0.5885 - y1_output_root_mean_squared_error: 0.4340 - y2_output_root_mean_squared_error: 0.7671 - val_loss: 1.1004 - val_y1_output_loss: 0.1723 - val_y2_output_loss: 0.9033 - val_y1_output_root_mean_squared_error: 0.4161 - val_y2_output_root_mean_squared_error: 0.9629
# Epoch 354/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.9427 - y1_output_loss: 0.2153 - y2_output_loss: 0.7274 - y1_output_root_mean_squared_error: 0.4656 - y2_output_root_mean_squared_error: 0.8520 - val_loss: 1.5087 - val_y1_output_loss: 0.2828 - val_y2_output_loss: 1.2546 - val_y1_output_root_mean_squared_error: 0.5357 - val_y2_output_root_mean_squared_error: 1.1053
# Epoch 355/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.7010 - y1_output_loss: 0.1647 - y2_output_loss: 0.5342 - y1_output_root_mean_squared_error: 0.4064 - y2_output_root_mean_squared_error: 0.7320 - val_loss: 1.0624 - val_y1_output_loss: 0.1868 - val_y2_output_loss: 0.8607 - val_y1_output_root_mean_squared_error: 0.4323 - val_y2_output_root_mean_squared_error: 0.9357
# Epoch 356/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5931 - y1_output_loss: 0.1758 - y2_output_loss: 0.4154 - y1_output_root_mean_squared_error: 0.4203 - y2_output_root_mean_squared_error: 0.6454 - val_loss: 1.5404 - val_y1_output_loss: 0.1758 - val_y2_output_loss: 1.4321 - val_y1_output_root_mean_squared_error: 0.4156 - val_y2_output_root_mean_squared_error: 1.1695
# Epoch 357/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.6591 - y1_output_loss: 0.1590 - y2_output_loss: 0.4980 - y1_output_root_mean_squared_error: 0.3990 - y2_output_root_mean_squared_error: 0.7071 - val_loss: 1.3200 - val_y1_output_loss: 0.2433 - val_y2_output_loss: 1.0982 - val_y1_output_root_mean_squared_error: 0.4901 - val_y2_output_root_mean_squared_error: 1.0391
# Epoch 358/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5228 - y1_output_loss: 0.1361 - y2_output_loss: 0.3832 - y1_output_root_mean_squared_error: 0.3702 - y2_output_root_mean_squared_error: 0.6211 - val_loss: 0.9424 - val_y1_output_loss: 0.1515 - val_y2_output_loss: 0.8090 - val_y1_output_root_mean_squared_error: 0.3870 - val_y2_output_root_mean_squared_error: 0.8903
# Epoch 359/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.5770 - y1_output_loss: 0.1506 - y2_output_loss: 0.4271 - y1_output_root_mean_squared_error: 0.3887 - y2_output_root_mean_squared_error: 0.6526 - val_loss: 0.8804 - val_y1_output_loss: 0.1578 - val_y2_output_loss: 0.7267 - val_y1_output_root_mean_squared_error: 0.3985 - val_y2_output_root_mean_squared_error: 0.8495
# Epoch 360/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.6629 - y1_output_loss: 0.1465 - y2_output_loss: 0.5177 - y1_output_root_mean_squared_error: 0.3830 - y2_output_root_mean_squared_error: 0.7185 - val_loss: 2.6016 - val_y1_output_loss: 0.3035 - val_y2_output_loss: 2.3247 - val_y1_output_root_mean_squared_error: 0.5416 - val_y2_output_root_mean_squared_error: 1.5193
# Epoch 361/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.7334 - y1_output_loss: 0.1797 - y2_output_loss: 0.5486 - y1_output_root_mean_squared_error: 0.4252 - y2_output_root_mean_squared_error: 0.7433 - val_loss: 0.9481 - val_y1_output_loss: 0.1774 - val_y2_output_loss: 0.7684 - val_y1_output_root_mean_squared_error: 0.4194 - val_y2_output_root_mean_squared_error: 0.8787
# Epoch 362/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.7178 - y1_output_loss: 0.1819 - y2_output_loss: 0.5356 - y1_output_root_mean_squared_error: 0.4258 - y2_output_root_mean_squared_error: 0.7324 - val_loss: 1.4671 - val_y1_output_loss: 0.4084 - val_y2_output_loss: 1.1162 - val_y1_output_root_mean_squared_error: 0.6114 - val_y2_output_root_mean_squared_error: 1.0456
# Epoch 363/500
# 614/614 [==============================] - 0s 128us/sample - loss: 1.1926 - y1_output_loss: 0.2387 - y2_output_loss: 0.9561 - y1_output_root_mean_squared_error: 0.4873 - y2_output_root_mean_squared_error: 0.9773 - val_loss: 1.2169 - val_y1_output_loss: 0.2943 - val_y2_output_loss: 0.9712 - val_y1_output_root_mean_squared_error: 0.5352 - val_y2_output_root_mean_squared_error: 0.9646
# Epoch 364/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.5475 - y1_output_loss: 0.1575 - y2_output_loss: 0.3925 - y1_output_root_mean_squared_error: 0.3977 - y2_output_root_mean_squared_error: 0.6239 - val_loss: 1.4577 - val_y1_output_loss: 0.2043 - val_y2_output_loss: 1.3162 - val_y1_output_root_mean_squared_error: 0.4484 - val_y2_output_root_mean_squared_error: 1.1210
# Epoch 365/500
# 520/614 [========================>.....] - ETA: 0s - loss: 0.6471 - y1_output_loss: 0.1441 - y2_output_loss: 0.5030 - y1_output_root_mean_squared_error: 0.3796 - y2_output_root_mean_squared_error: 0.7092

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
