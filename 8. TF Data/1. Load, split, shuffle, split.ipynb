# %% [markdown]
# # Horses or Humans

# %%
# !pip install tensorflow_addons
# Out:
# /bin/bash: /home/sharoon/miniconda3/envs/tf112/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Requirement already satisfied: tensorflow_addons in /home/sharoon/miniconda3/envs/tf112/lib/python3.9/site-packages (0.18.0)
# Requirement already satisfied: typeguard>=2.7 in /home/sharoon/miniconda3/envs/tf112/lib/python3.9/site-packages (from tensorflow_addons) (2.13.3)
# Requirement already satisfied: packaging in /home/sharoon/.local/lib/python3.9/site-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/sharoon/.local/lib/python3.9/site-packages (from packaging->tensorflow_addons) (3.0.9)

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow_addons as tfa
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'


data = tfds.load('horses_or_humans', split='train', as_supervised=True)
val_data = tfds.load('horses_or_humans', split='test', as_supervised=True)

# %%
train_batches = data.shuffle(100).batch(32)
validation_batches = val_data.batch(32)

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', 
                                      input_shape=(300, 300, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])


model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_batches, epochs=10, validation_data=validation_batches, validation_steps=1)
# Out:
# Epoch 1/10
# 33/33 [==============================] - 4s 103ms/step - loss: 6.4086 - accuracy: 0.7069 - val_loss: 0.8891 - val_accuracy: 0.7812
# Epoch 2/10
# 33/33 [==============================] - 3s 98ms/step - loss: 0.1235 - accuracy: 0.9562 - val_loss: 0.8405 - val_accuracy: 0.8125
# Epoch 3/10
# 33/33 [==============================] - 3s 98ms/step - loss: 0.0515 - accuracy: 0.9834 - val_loss: 0.2263 - val_accuracy: 0.9375
# Epoch 4/10
# 33/33 [==============================] - 3s 98ms/step - loss: 0.0362 - accuracy: 0.9873 - val_loss: 1.8121 - val_accuracy: 0.8438
# Epoch 5/10
# 33/33 [==============================] - 3s 98ms/step - loss: 0.0539 - accuracy: 0.9834 - val_loss: 0.6897 - val_accuracy: 0.9375
# Epoch 6/10
# 33/33 [==============================] - 3s 99ms/step - loss: 0.0103 - accuracy: 0.9971 - val_loss: 0.6889 - val_accuracy: 0.9375
# Epoch 7/10
# 33/33 [==============================] - 3s 99ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.4224 - val_accuracy: 0.8750
# Epoch 8/10
# 33/33 [==============================] - 3s 102ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.3078 - val_accuracy: 0.9062
# Epoch 9/10
# 33/33 [==============================] - 3s 101ms/step - loss: 3.1052e-04 - accuracy: 1.0000 - val_loss: 1.2288 - val_accuracy: 0.9062
# Epoch 10/10
# 33/33 [==============================] - 3s 102ms/step - loss: 1.3026e-04 - accuracy: 1.0000 - val_loss: 1.3362 - val_accuracy: 0.9062
